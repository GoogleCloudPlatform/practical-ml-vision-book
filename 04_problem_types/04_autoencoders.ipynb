# %%
from IPython.display import Markdown as md

### change to reflect your notebook
_nb_loc = "04_problem_types/04_autoencoders.ipynb"
_nb_title = "Autoencoders"

### no need to change any of this
_nb_safeloc = _nb_loc.replace('/', '%2F')
md("""
<table class="tfo-notebook-buttons" align="left">
  <td>
    <a target="_blank" href="https://console.cloud.google.com/ai-platform/notebooks/deploy-notebook?name={1}&url=https%3A%2F%2Fgithub.com%2FGoogleCloudPlatform%2Fpractical-ml-vision-book%2Fblob%2Fmaster%2F{2}&download_url=https%3A%2F%2Fgithub.com%2FGoogleCloudPlatform%2Fpractical-ml-vision-book%2Fraw%2Fmaster%2F{2}">
    <img src="https://raw.githubusercontent.com/GoogleCloudPlatform/practical-ml-vision-book/master/logo-cloud.png"/> Run in AI Platform Notebook</a>
  </td>
  </td>
  <td>
    <a target="_blank" href="https://colab.research.google.com/github/GoogleCloudPlatform/practical-ml-vision-book/blob/master/{0}">
    <img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
  </td>
  <td>
    <a target="_blank" href="https://github.com/GoogleCloudPlatform/practical-ml-vision-book/blob/master/{0}">
    <img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
  </td>
  <td>
    <a href="https://raw.githubusercontent.com/GoogleCloudPlatform/practical-ml-vision-book/master/{0}">
    <img src="https://www.tensorflow.org/images/download_logo_32px.png" />Download notebook</a>
  </td>
</table>
""".format(_nb_loc, _nb_title, _nb_safeloc))
# Out:
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://console.cloud.google.com/ai-platform/notebooks/deploy-notebook?name=Autoencoders&url=https%3A%2F%2Fgithub.com%2FGoogleCloudPlatform%2Fpractical-ml-vision-book%2Fblob%2Fmaster%2F04_problem_types%2F04_autoencoders.ipynb&download_url=https%3A%2F%2Fgithub.com%2FGoogleCloudPlatform%2Fpractical-ml-vision-book%2Fraw%2Fmaster%2F04_problem_types%2F04_autoencoders.ipynb">
#     <img src="https://raw.githubusercontent.com/GoogleCloudPlatform/practical-ml-vision-book/master/logo-cloud.png"/> Run in AI Platform Notebook</a>
#   </td>
#   </td>
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/GoogleCloudPlatform/practical-ml-vision-book/blob/master/04_problem_types/04_autoencoders.ipynb">
#     <img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/GoogleCloudPlatform/practical-ml-vision-book/blob/master/04_problem_types/04_autoencoders.ipynb">
#     <img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
#   <td>
#     <a href="https://raw.githubusercontent.com/GoogleCloudPlatform/practical-ml-vision-book/master/04_problem_types/04_autoencoders.ipynb">
#     <img src="https://www.tensorflow.org/images/download_logo_32px.png" />Download notebook</a>
#   </td>
# </table>

# %% [markdown]
# # Autoencoders

# %% [markdown]
# ## Enable GPU
# This notebook and pretty much every other notebook in this repository will run faster if you are using a GPU.
#
# On Colab:
# * Navigate to Edit→Notebook Settings
# * Select GPU from the Hardware Accelerator drop-down
#
# On Cloud AI Platform Notebooks:
# * Navigate to https://console.cloud.google.com/ai-platform/notebooks
# * Create an instance with a GPU or select your instance and add a GPU
#
# Next, we'll confirm that we can connect to the GPU with tensorflow:

# %%
import tensorflow as tf
print(tf.version.VERSION)
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# 2.3.0
# Found GPU at: /device:GPU:0

# %%
# Import libraries and modules
import matplotlib.pyplot as plt
import numpy as np
print(np.__version__)
np.set_printoptions(threshold=np.inf)
# Out:
# 1.18.5

# %% [markdown]
# ## Vanilla Autoencoders

# %% [markdown]
# For a vanilla autoencoder, we use just basic `Dense` layers for both the encoder and decoder.

# %%
# Create the encoder.
latent_dim = 512
vanilla_encoder = tf.keras.Sequential(
    [
        tf.keras.Input(shape=(28, 28, 1)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(units=1024),
        tf.keras.layers.LeakyReLU(alpha=0.2),
        tf.keras.layers.Dense(units=512),
        tf.keras.layers.LeakyReLU(alpha=0.2),
        tf.keras.layers.Dense(units=256),
        tf.keras.layers.LeakyReLU(alpha=0.2),
        tf.keras.layers.Dense(units=latent_dim),
    ],
    name="vanilla_encoder"
)
vanilla_encoder.summary()
# Out:
# Model: "vanilla_encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              803840
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               131584
# =================================================================
# Total params: 1,591,552
# Trainable params: 1,591,552
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Plot encoder model.
tf.keras.utils.plot_model(
    model=vanilla_encoder,
    to_file="vanilla_encoder_model.png",
    show_shapes=True,
    show_layer_names=True
)

# %%
# Create the decoder.
latent_dim = 512
vanilla_decoder = tf.keras.Sequential(
    [
        tf.keras.Input(shape=(latent_dim,)),
        tf.keras.layers.Dense(units=256),
        tf.keras.layers.LeakyReLU(alpha=0.2),
        tf.keras.layers.Dense(units=512),
        tf.keras.layers.LeakyReLU(alpha=0.2),
        tf.keras.layers.Dense(units=1024),
        tf.keras.layers.LeakyReLU(alpha=0.2),
        tf.keras.layers.Dense(units=28 * 28 * 1, activation="tanh"),
        tf.keras.layers.Reshape(target_shape=(28, 28, 1))
    ],
    name="vanilla_decoder"
)
vanilla_decoder.summary()
# Out:
# Model: "vanilla_decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 256)               131328
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               131584
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 784)               803600
# _________________________________________________________________
# reshape (Reshape)            (None, 28, 28, 1)         0
# =================================================================
# Total params: 1,591,824
# Trainable params: 1,591,824
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Plot decoder model.
tf.keras.utils.plot_model(
    model=vanilla_decoder,
    to_file="vanilla_decoder_model.png",
    show_shapes=True,
    show_layer_names=True
)

# %% [markdown]
# We'll create a custom `Model` class named `Autoencoder` that we can use to facilitate training of our encoder and decoder networks.

# %%
class Autoencoder(tf.keras.Model):
    """Custom model for training an autoencoder.

    Attributes:
        encoder: Keras `Model`, the encoder network.
        decoder: Keras `Model`, the decoder network.
        latent_dim: int, the latent vector dimension length.
        encoder_optimizer: Keras `Optimizer`, optimizer for
            encoder network.
        decoder_optimizer: Keras `Optimizer`, optimizer for decoder
            network.
        loss_fn: Keras `Loss`, loss function for training both networks.
    """
    def __init__(self, encoder, decoder, latent_dim):
        """Instantiates `Autoencoder` model class.

        Args:
            encoder: Keras `Model`, the encoder network.
            decoder: Keras `Model`, the decoder network.
            latent_dim: int, the latent vector dimension length.
        """
        super(Autoencoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.latent_dim = latent_dim

    def compile(self, encoder_optimizer, decoder_optimizer, loss_fn):
        """Overrides base `Model` class' compile method.

        Args:
            encoder_optimizer: Keras `Optimizer`, optimizer for
                encoder network.
            decoder_optimizer: Keras `Optimizer`, optimizer for decoder
                network.
            loss_fn: Keras `Loss`, loss function for training both networks.
        """
        super(Autoencoder, self).compile()
        self.encoder_optimizer = encoder_optimizer
        self.decoder_optimizer = decoder_optimizer
        self.loss_fn = loss_fn

    def train_step(self, images):
        """Trains `Autoencoder` for one step.

        Args:
            images: tensor, rank 4 tensor of images with shape
                (batch_size, height, width, depth).

        Returns:
            losses: dict, dictionary containing scalar loss.
        """
        if isinstance(images, tuple):
            images = images[0]

        with tf.GradientTape(persistent=True) as tape:
            # Encode images into latent vector/code.
            latent_vectors = self.encoder(inputs=images)

            # Generate reconstructed images from latent vectors.
            reconstructed_images = self.decoder(inputs=latent_vectors)

            loss = self.loss_fn(
                y_true=images, y_pred=reconstructed_images
            )

        encoder_grads = tape.gradient(
            target=loss,
            sources=self.encoder.trainable_weights
        )

        decoder_grads = tape.gradient(
            target=loss,
            sources=self.decoder.trainable_weights
        )

        self.encoder_optimizer.apply_gradients(
            grads_and_vars=zip(encoder_grads, self.encoder.trainable_weights)
        )

        self.decoder_optimizer.apply_gradients(
            grads_and_vars=zip(decoder_grads, self.decoder.trainable_weights)
        )

        losses = {"loss": loss}

        return losses

    def call(self, images):
        # Encode images into latent vector/code.
        latent_vectors = self.encoder(inputs=images)

        # Generate reconstructed images from latent vectors.
        reconstructed_images = self.decoder(inputs=latent_vectors)

        loss = self.loss_fn(
            y_true=images, y_pred=reconstructed_images
        )

        self.add_metric(value=loss, name="loss", aggregation="mean")
        self.add_metric(value=tf.sqrt(x=loss), name="rmse", aggregation="mean")

        return {"loss": loss}

# %%
def create_dataset(batch_size, training):
    """Creates training dataset.

    Args:
        batch_size: int, number of elements in a mini-batch.
        training: bool, whether training or not.

    Returns:
        dataset: `Dataset`, dataset object for training using MNIST.
    """
    # Get and format MNIST data.
    (x_train, _), (x_test, _) = tf.keras.datasets.mnist.load_data()

    if training:
        images = x_train
    else:
        images = x_test

    images = (images.astype("float32") - 127.5) / 255.0
    images = np.reshape(images, newshape=(-1, 28, 28, 1))

    # Create tf.data.Dataset for training.
    dataset = tf.data.Dataset.from_tensor_slices(tensors=images)
    if training:
        dataset = dataset.shuffle(buffer_size=70000)
    dataset = dataset.batch(batch_size=batch_size)

    return dataset

# %%
# Instantiate an Autoencoder instance using our vanilla encoder and decoder.
vanilla_autoencoder = Autoencoder(
    encoder=vanilla_encoder, decoder=vanilla_decoder, latent_dim=latent_dim
)

vanilla_autoencoder.compile(
    encoder_optimizer=tf.keras.optimizers.Adam(
        learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7
    ),
    decoder_optimizer=tf.keras.optimizers.Adam(
        learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7
    ),
    loss_fn=tf.keras.losses.MeanSquaredError()
)

# Train vanilla autoencoder model.
vanilla_autoencoder_history = vanilla_autoencoder.fit(
    create_dataset(batch_size=128, training=True),
    epochs=30,
    validation_data=create_dataset(batch_size=128, training=False)
)
# Out:
# Epoch 1/30
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0214 - val_loss: 0.0102 - val_rmse: 0.1009
# Epoch 2/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0091 - val_loss: 0.0077 - val_rmse: 0.0879
# Epoch 3/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0072 - val_loss: 0.0065 - val_rmse: 0.0808
# Epoch 4/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0062 - val_loss: 0.0057 - val_rmse: 0.0755
# Epoch 5/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0056 - val_loss: 0.0056 - val_rmse: 0.0747
# Epoch 6/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0052 - val_loss: 0.0056 - val_rmse: 0.0749
# Epoch 7/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0048 - val_loss: 0.0046 - val_rmse: 0.0681
# Epoch 8/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0045 - val_loss: 0.0044 - val_rmse: 0.0663
# Epoch 9/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0044 - val_loss: 0.0042 - val_rmse: 0.0645
# Epoch 10/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0041 - val_loss: 0.0050 - val_rmse: 0.0705
# Epoch 11/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0041 - val_loss: 0.0039 - val_rmse: 0.0624
# Epoch 12/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0039 - val_loss: 0.0039 - val_rmse: 0.0625
# Epoch 13/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0038 - val_loss: 0.0039 - val_rmse: 0.0622
# Epoch 14/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0037 - val_loss: 0.0044 - val_rmse: 0.0664
# Epoch 15/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0036 - val_loss: 0.0035 - val_rmse: 0.0594
# Epoch 16/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0035 - val_loss: 0.0036 - val_rmse: 0.0598
# Epoch 17/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0034 - val_loss: 0.0035 - val_rmse: 0.0595
# Epoch 18/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0033 - val_loss: 0.0034 - val_rmse: 0.0585
# Epoch 19/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0033 - val_loss: 0.0034 - val_rmse: 0.0587
# Epoch 20/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0032 - val_loss: 0.0032 - val_rmse: 0.0566
# Epoch 21/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0031 - val_loss: 0.0031 - val_rmse: 0.0558
# Epoch 22/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0031 - val_loss: 0.0031 - val_rmse: 0.0561
# Epoch 23/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0030 - val_loss: 0.0032 - val_rmse: 0.0566
# Epoch 24/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0030 - val_loss: 0.0031 - val_rmse: 0.0559
# Epoch 25/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0029 - val_loss: 0.0032 - val_rmse: 0.0567
# Epoch 26/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0029 - val_loss: 0.0031 - val_rmse: 0.0553
# Epoch 27/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0029 - val_loss: 0.0031 - val_rmse: 0.0557
# Epoch 28/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0028 - val_loss: 0.0029 - val_rmse: 0.0543
# Epoch 29/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0027 - val_loss: 0.0030 - val_rmse: 0.0546
# Epoch 30/30
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0027 - val_loss: 0.0029 - val_rmse: 0.0539

# %% [markdown]
# Let's plot the loss history and some generated images using our trained model.

# %%
def plot_loss_history(history):
    """Plots loss history.

    Args:
        history: `keras.callbacks.History`, history object from training job.
    """
    plt.plot(history.history["loss"])
    plt.plot(history.history["val_loss"])
    plt.title("Training loss")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend(["train_loss", "val_loss"], loc="upper left")
    plt.show()

# %%
def plot_rmse(history):
    """Plots RMSE history.

    Args:
        history: `keras.callbacks.History`, history object from training job.
    """
    plt.plot(history.history["val_rmse"])
    plt.title("Validation Metrics")
    plt.ylabel("RMSE")
    plt.xlabel("Epoch")
    plt.show()

# %%
def plot_images(images):
    """Plots images.

    Args:
        images: np.array, array of images of
            [num_images, image_size, image_size, num_channels].
    """
    num_images = len(images)

    plt.figure(figsize=(20, 20))
    for i in range(num_images):
        image = images[i]
        plt.subplot(1, num_images, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(
            tf.reshape(image, image.shape[:-1]),
            cmap="gray_r"
        )
    plt.show()

# %%
plot_loss_history(history=vanilla_autoencoder_history)

# %%
plot_rmse(history=vanilla_autoencoder_history)

# %% [markdown]
# Autoencoder is great at reconstruction.

# %%
dataset_iter = iter(create_dataset(batch_size=12, training=False))
batch = next(dataset_iter)
plot_images(
    images=vanilla_autoencoder.decoder(
        inputs=vanilla_autoencoder.encoder(inputs=batch)
    )
)

# %% [markdown]
# However, the latent space isn't nicely regularized therefore decoding a user provided latent vector performs poorly.

# %%
plot_images(
    images=vanilla_autoencoder.decoder(
        inputs=tf.random.normal(shape=(12, latent_dim))
    )
)

# %% [markdown]
# ## DC-Autoencoder

# %% [markdown]
# A Deep-convolutional autoencoder (DC-Autoencoder) uses convolutional (`Conv2D`) and deconvolutional (`Conv2DTranspose`) instead of `Dense` layers for the encoder and decoder respectively.

# %%
# Create the encoder
latent_dim = 512
dc_encoder = tf.keras.Sequential(
    [
        tf.keras.Input(shape=(28, 28, 1)),
        tf.keras.layers.Conv2D(
            filters=64, kernel_size=(3, 3), strides=(1, 1), padding="same"
        ),
        tf.keras.layers.LeakyReLU(alpha=0.2),
        tf.keras.layers.Conv2D(
            filters=128, kernel_size=(3, 3), strides=(2, 2), padding="same"
        ),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.LeakyReLU(alpha=0.2),
        tf.keras.layers.Conv2D(
            filters=128, kernel_size=(3, 3), strides=(2, 2), padding="same"
        ),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.LeakyReLU(alpha=0.2),
        tf.keras.layers.Conv2D(
            filters=256, kernel_size=(3, 3), strides=(2, 2), padding="same"
        ),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.LeakyReLU(alpha=0.2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(units=latent_dim)
    ],
    name="dc_encoder"
)
dc_encoder.summary()
# Out:
# Model: "dc_encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 64)        640
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# batch_normalization (BatchNo (None, 14, 14, 128)       512
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 128)         147584
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 7, 7, 128)         512
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 256)         295168
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               2097664
# =================================================================
# Total params: 2,616,960
# Trainable params: 2,615,936
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
# Plot decoder model.
tf.keras.utils.plot_model(
    model=dc_encoder,
    to_file="dc_encoder_model.png",
    show_shapes=True,
    show_layer_names=True
)

# %%
# Create the decoder
latent_dim = 512
dc_decoder = tf.keras.Sequential(
    [
        tf.keras.Input(shape=(latent_dim,)),
        tf.keras.layers.Dense(units=7 * 7 * 256),
        tf.keras.layers.LeakyReLU(alpha=0.2),
        tf.keras.layers.Reshape(target_shape=(7, 7, 256)),
        tf.keras.layers.Conv2DTranspose(
            filters=128, kernel_size=(4, 4), strides=(2, 2), padding="same"
        ),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.LeakyReLU(alpha=0.2),
        tf.keras.layers.Conv2DTranspose(
            filters=128, kernel_size=(4, 4), strides=(2, 2), padding="same"
        ),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.LeakyReLU(alpha=0.2),
        tf.keras.layers.Conv2DTranspose(
            filters=1,
            kernel_size=(3, 3),
            strides=(1, 1),
            padding="same",
            activation="tanh"
        )
    ],
    name="dc_decoder"
)
dc_decoder.summary()
# Out:
# Model: "dc_decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 12544)             6435072
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 12544)             0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 14, 14, 128)       524416
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 28, 28, 128)       262272
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 28, 28, 1)         1153
# =================================================================
# Total params: 7,223,937
# Trainable params: 7,223,425
# Non-trainable params: 512
# _________________________________________________________________

# %%
# Plot decoder model.
tf.keras.utils.plot_model(
    model=dc_decoder,
    to_file="dc_decoder_model.png",
    show_shapes=True,
    show_layer_names=True
)

# %%
# Instantiate an `Autoencoder` instance using our DC encoder and decoder.
dc_autoencoder = Autoencoder(
    encoder=dc_encoder, decoder=dc_decoder, latent_dim=latent_dim
)

dc_autoencoder.compile(
    encoder_optimizer=tf.keras.optimizers.Adam(
        learning_rate=0.0002, beta_1=0.5, beta_2=0.999, epsilon=1e-8
    ),
    decoder_optimizer=tf.keras.optimizers.Adam(
        learning_rate=0.0002, beta_1=0.5, beta_2=0.999, epsilon=1e-8
    ),
    loss_fn=tf.keras.losses.MeanSquaredError()
)

# Train DC-Autoencoder model.
dc_autoencoder_history = dc_autoencoder.fit(
    create_dataset(batch_size=128, training=True),
    epochs=30,
    validation_data=create_dataset(batch_size=128, training=False)
)
# Out:
# Epoch 1/30
# 469/469 [==============================] - 31s 66ms/step - loss: 0.0241 - val_loss: 0.0059 - val_rmse: 0.0768
# Epoch 2/30
# 469/469 [==============================] - 30s 65ms/step - loss: 0.0043 - val_loss: 0.0031 - val_rmse: 0.0556
# Epoch 3/30
# 469/469 [==============================] - 30s 64ms/step - loss: 0.0030 - val_loss: 0.0024 - val_rmse: 0.0486
# Epoch 4/30
# 469/469 [==============================] - 30s 64ms/step - loss: 0.0024 - val_loss: 0.0020 - val_rmse: 0.0450
# Epoch 5/30
# 469/469 [==============================] - 30s 64ms/step - loss: 0.0020 - val_loss: 0.0018 - val_rmse: 0.0425
# Epoch 6/30
# 469/469 [==============================] - 30s 64ms/step - loss: 0.0017 - val_loss: 0.0016 - val_rmse: 0.0403
# Epoch 7/30
# 469/469 [==============================] - 30s 64ms/step - loss: 0.0015 - val_loss: 0.0015 - val_rmse: 0.0384
# Epoch 8/30
# 469/469 [==============================] - 30s 64ms/step - loss: 0.0014 - val_loss: 0.0013 - val_rmse: 0.0359
# Epoch 9/30
# 469/469 [==============================] - 30s 64ms/step - loss: 0.0013 - val_loss: 0.0016 - val_rmse: 0.0396
# Epoch 10/30
# 469/469 [==============================] - 30s 64ms/step - loss: 0.0012 - val_loss: 0.0011 - val_rmse: 0.0326
# Epoch 11/30
# 469/469 [==============================] - 30s 64ms/step - loss: 0.0011 - val_loss: 0.0011 - val_rmse: 0.0330
# Epoch 12/30
# 469/469 [==============================] - 30s 64ms/step - loss: 0.0010 - val_loss: 0.0010 - val_rmse: 0.0319
# Epoch 13/30
# 469/469 [==============================] - 30s 64ms/step - loss: 9.4539e-04 - val_loss: 9.9008e-04 - val_rmse: 0.0314
# Epoch 14/30
# 469/469 [==============================] - 30s 64ms/step - loss: 9.0217e-04 - val_loss: 0.0013 - val_rmse: 0.0360
# Epoch 15/30
# 469/469 [==============================] - 30s 64ms/step - loss: 8.3672e-04 - val_loss: 8.7848e-04 - val_rmse: 0.0296
# Epoch 16/30
# 469/469 [==============================] - 30s 64ms/step - loss: 7.9624e-04 - val_loss: 7.8807e-04 - val_rmse: 0.0280
# Epoch 17/30
# 469/469 [==============================] - 30s 64ms/step - loss: 7.5210e-04 - val_loss: 7.1948e-04 - val_rmse: 0.0268
# Epoch 18/30
# 469/469 [==============================] - 30s 64ms/step - loss: 7.0867e-04 - val_loss: 6.7908e-04 - val_rmse: 0.0260
# Epoch 19/30
# 469/469 [==============================] - 30s 64ms/step - loss: 6.7459e-04 - val_loss: 7.0840e-04 - val_rmse: 0.0266
# Epoch 20/30
# 469/469 [==============================] - 30s 64ms/step - loss: 6.3973e-04 - val_loss: 6.1169e-04 - val_rmse: 0.0247
# Epoch 21/30
# 469/469 [==============================] - 30s 64ms/step - loss: 6.0143e-04 - val_loss: 5.9366e-04 - val_rmse: 0.0243
# Epoch 22/30
# 469/469 [==============================] - 30s 64ms/step - loss: 5.7994e-04 - val_loss: 5.5188e-04 - val_rmse: 0.0234
# Epoch 23/30
# 469/469 [==============================] - 30s 64ms/step - loss: 5.4959e-04 - val_loss: 5.6743e-04 - val_rmse: 0.0238
# Epoch 24/30
# 469/469 [==============================] - 30s 64ms/step - loss: 5.1766e-04 - val_loss: 5.4311e-04 - val_rmse: 0.0233
# Epoch 25/30
# 469/469 [==============================] - 30s 64ms/step - loss: 4.9637e-04 - val_loss: 6.4380e-04 - val_rmse: 0.0253
# Epoch 26/30
# 469/469 [==============================] - 30s 64ms/step - loss: 4.7185e-04 - val_loss: 6.1265e-04 - val_rmse: 0.0247
# Epoch 27/30
# 469/469 [==============================] - 30s 64ms/step - loss: 4.5193e-04 - val_loss: 5.8603e-04 - val_rmse: 0.0242
# Epoch 28/30
# 469/469 [==============================] - 30s 64ms/step - loss: 4.2800e-04 - val_loss: 4.4695e-04 - val_rmse: 0.0211
# Epoch 29/30
# 469/469 [==============================] - 30s 64ms/step - loss: 4.1104e-04 - val_loss: 4.2378e-04 - val_rmse: 0.0205
# Epoch 30/30
# 469/469 [==============================] - 30s 64ms/step - loss: 3.9427e-04 - val_loss: 4.4612e-04 - val_rmse: 0.0211

# %% [markdown]
# Let's plot the loss history and some generated images using our trained model.

# %%
plot_loss_history(history=dc_autoencoder_history)

# %%
plot_rmse(history=dc_autoencoder_history)

# %% [markdown]
# Autoencoder is great at reconstruction.

# %%
dataset_iter = iter(create_dataset(batch_size=12, training=False))
batch = next(dataset_iter)
plot_images(
    images=dc_autoencoder.decoder(
        inputs=dc_autoencoder.encoder(inputs=batch)
    )
)

# %% [markdown]
# However, the latent space isn't nicely regularized therefore decoding a user provided latent vector performs poorly.

# %%
plot_images(
    images=dc_autoencoder.decoder(
        inputs=tf.random.normal(shape=(12, latent_dim))
    )
)
